# %% [markdown]
# Iris - Classifier Models

# %%
import pandas as  pd
import numpy as np
from  sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score,r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
df = pd.read_csv(r"C:\Users\HP\Downloads\code\iris flower.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#KNeigborsClassifier
x = df.drop(columns=["Id","Species"])
y = df["Species"]

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size= 0.2, random_state= 23)
model= KNeighborsClassifier()
model.fit(x_train,y_train)
p = model.predict(x_test)
ak = accuracy_score(y_test,p)
bk = precision_score(y_test,p, average= "weighted")
ck = recall_score(y_test,p, average= "weighted")
print("accuracy: ", a)
print("precisin: ", b)
print("recall: ", c)
# Out:
# accuracy:  1.0
# precisin:  [1. 1. 1.]
# recall:  [1. 1. 1.]

# %%
#DesicisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
p = model.predict(x_test)
ad = accuracy_score(y_test,p)
bd = precision_score(y_test,p, average= "weighted")
cd = recall_score(y_test, p , average= "weighted")
print("accuracy: ", a)
print("precisin: ", b)
print("recall: ", c)
# Out:
# accuracy:  1.0
# precisin:  [1. 1. 1.]
# recall:  [1. 1. 1.]

# %%
#RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train,y_train)
p = model.predict(x_test)
ar = accuracy_score(y_test,p)
br = precision_score(y_test,p, average= "weighted")
cr = recall_score(y_test, p , average= "weighted")
print("accuracy: ", a)
print("precisin: ", b)
print("recall: ", c)
# Out:
# accuracy:  1.0
# precisin:  [1. 1. 1.]
# recall:  [1. 1. 1.]

# %%
#Logistic Regression
model = LogisticRegression()
model.fit(x_train,y_train)
p = model.predict(x_test)
alr = accuracy_score(y_test,p)
blr = precision_score(y_test,p, average= "weighted")
clr = recall_score(y_test, p , average= "weighted")
print("accuracy: ", a)
print("precisin: ", b)
print("recall: ", c)
# Out:
# accuracy:  1.0
# precisin:  [1. 1. 1.]
# recall:  [1. 1. 1.]

# %% [markdown]
# Diabetes - Regressor Models

# %%
#KNeighborRegressi
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
from sklearn.datasets import load_diabetes
d = load_diabetes()

df = pd.DataFrame(d.data , columns=d.feature_names)
df["target"]= d.target

# %%
x = df.drop(columns="target")
y =df["target"]
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size= 0.25, random_state= 23)
model = KNeighborsRegressor()
model.fit(x_train,y_train)
p = model.predict(x_test)
rk  = r2_score(y_test,p)
mak = mean_absolute_error(y_test,p)
mek = mean_squared_error(y_test,p)
print("r2 score: ",r)
print("mean absolute error: ", ma)
print("mean squared error: ", me)
# Out:
# r2 score:  0.3893454215287261
# mean absolute error:  46.880090090090086
# mean squared error:  3449.3161630630634

# %%
#linearregression
model = LinearRegression()
model.fit(x_train,y_train)
p = model.predict(x_test)
rl  = r2_score(y_test,p)
mal = mean_absolute_error(y_test,p)
mel = mean_squared_error(y_test,p)
print("r2 score: ",r)
print("mean absolute error: ", ma)
print("mean squared error: ", me)
# Out:
# r2 score:  0.3893454215287261
# mean absolute error:  46.880090090090086
# mean squared error:  3449.3161630630634

# %%
#DesicionTreeRegression
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
p = model.predict(x_test)
rd  = r2_score(y_test,p)
mad = mean_absolute_error(y_test,p)
med = mean_squared_error(y_test,p)
print("r2 score: ",r)
print("mean absolute error: ", ma)
print("mean squared error: ", me)
# Out:
# r2 score:  0.3893454215287261
# mean absolute error:  46.880090090090086
# mean squared error:  3449.3161630630634

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
#RandonForestRegresssion
model = RandomForestRegressor()
model.fit(x_train,y_train)
p = model.predict(x_test)
rr  = r2_score(y_test,p)
mar = mean_absolute_error(y_test,p)
mer = mean_squared_error(y_test,p)
print("r2 score: ",r)
print("mean absolute error: ", ma)
print("mean squared error: ", me)
# Out:
# r2 score:  0.3893454215287261
# mean absolute error:  46.880090090090086
# mean squared error:  3449.3161630630634

# %% [markdown]
# DataFrame(iris classification)

# %%
data  = pd.DataFrame({
                    "index": [0,1,2,3],
                    "Algorithms": ["KNNClassification","DecisionTreeClassifier","RandomForestClassifier","LogisticRegression"],
                    "Accuracy": [ak,ad,ar,alr],
                    "precision":[bk,bd,br,blr],
                    "Recall":[ck,cd,cr,blr]})
data.set_index('index', inplace= True)
data
# Out:
#                    Algorithms  Accuracy  precision    Recall
# index
# 0           KNNClassification  1.000000    1.00000  1.000000
# 1      DecisionTreeClassifier  0.966667    0.97037  0.966667
# 2      RandomForestClassifier  0.966667    0.97037  0.966667
# 3          LogisticRegression  1.000000    1.00000  1.000000

# %%
data["Algorithms"]
# Out:
# index
# 0         KNNClassification
# 1    DecisionTreeClassifier
# 2    RandomForestClassifier
# 3        LogisticRegression
# Name: Algorithms, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sn
x = data["Algorithms"]
y = data["Accuracy"]
i = data["precision"]
z = data["Recall"]

plt.bar(x,y)
plt.xlabel("Algorithms")
plt.ylabel("accuracy")
plt.legend()
plt.show()


plt.bar(x,i)
plt.xlabel("Algorithms")
plt.ylabel("precision")
plt.legend()
plt.show()


plt.bar(x,z)
plt.xlabel("Algorithms")
plt.ylabel("recall")
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\680175524.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\680175524.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\680175524.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# DataFrame(Diabetes Regression)

# %%
data1 = pd.DataFrame({
                    "index":[0,1,2,3],
                    "Algorithms": ["KNNRegression","DecisionTreeRegression","RandomForestRegression","LinearRegression"],
                    "r2square": [rk,rd,rr,rl],
                    "mean absolute error":[mak,mad,mar,mal],
                    "mean squared error":[mek,med,mer,mel],
})

data1.set_index('index', inplace= True)
data1
# Out:
#                    Algorithms  r2square  mean absolute error  \
# index
# 0               KNNRegression  0.396759            44.828829
# 1      DecisionTreeRegression -0.288541            68.576577
# 2      RandomForestRegression  0.413755            45.620360
# 3            LinearRegression  0.471726            42.913347
#
#        mean squared error
# index
# 0             3407.442162
# 1             7278.396396
# 2             3311.439022
# 3             2983.984638

# %%
x = data1["Algorithms"]
y = data1["r2square"]
i = data1["mean absolute error"]
z = data1["mean squared error"]

plt.bar(x,y)
plt.xlabel("Algorithms")
plt.ylabel("r2squared")
plt.legend()
plt.show()


plt.bar(x,i)
plt.xlabel("Algorithms")
plt.ylabel("mean absolute error")
plt.legend()
plt.show()


plt.bar(x,z)
plt.xlabel("Algorithms")
plt.ylabel("mean squared error")
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\415838042.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\415838042.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\HP\AppData\Local\Temp\ipykernel_20772\415838042.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
